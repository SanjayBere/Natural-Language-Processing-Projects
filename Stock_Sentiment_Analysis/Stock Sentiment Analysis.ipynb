# %% [markdown]
# # Stock Sentiment Analysis

# %%
#laod the data 
import pandas as pd 
import re

# %%
df = pd.read_csv("D://AppliedAICourse//Projects//NLP//Stock Sentiment Analysis//Stock News Headlines.csv",encoding="ISO-8859-1")
df.head(100)
# Out:
#           Date  Label                                               Top1  \
# 0   2000-01-03      0  A 'hindrance to operations': extracts from the...
# 1   2000-01-04      0                                          Scorecard
# 2   2000-01-05      0                  Coventry caught on counter by Flo
# 3   2000-01-06      1                      Pilgrim knows how to progress
# 4   2000-01-07      1                               Hitches and Horlocks
# ..         ...    ...                                                ...
# 95  2000-05-19      1                  Day eleven: Reasons to be fearful
# 96  2000-05-22      0           Tories led by rabble rouser says Kennedy
# 97  2000-05-23      0            ICC to look at Malik match-fixing tapes
# 98  2000-05-24      0              Phillips to rouse the beast in Brazil
# 99  2000-05-25      1                                         Scoreboard
#
#                                                  Top2  \
# 0                                           Scorecard
# 1                                 The best lake scene
# 2                  United's rivals on the road to Rio
# 3                                 Thatcher facing ban
# 4                      Beckham off but United survive
# ..                                                ...
# 95                                        Non-fiction
# 96                        Kingston breaks out of Hull
# 97               Halifax drops cash machine surcharge
# 98  Malik banned for life as Pakistan blows the wh...
# 99                    Youhana restores Pakistan pride
#
#                                              Top3  \
# 0                 Hughes' instant hit buoys Blues
# 1                   Leader: German sleaze inquiry
# 2   Thatcher issues defence before trial by video
# 3         McIlroy calls for Irish fighting spirit
# 4                         Breast cancer screening
# ..                                            ...
# 95                                     Wigged out
# 96                         Trail of night wonders
# 97           Exchange merger survives German vote
# 98  Notre-Dame de Paris, Dominion Theatre, London
# 99                    Exchange turns on the charm
#
#                                              Top4  \
# 0        Jack gets his skates on at ice-cold Alex
# 1                                   Cheerio, boyo
# 2   Police help Smith lay down the law at Everton
# 3                 Leicester bin stadium blueprint
# 4                                     Alan Parker
# ..                                            ...
# 95                                Our finest hour
# 96       Boo liquidators make 220 staff redundant
# 97                     Stories From a Mean Street
# 98             Developer pushes for city shopping
# 99                   SFO chief hits at new regime
#
#                                              Top5  \
# 0          Chaos as Maracana builds up for United
# 1                        The main recommendations
# 2     Tale of Trautmann bears two more retellings
# 3                  United braced for Mexican wave
# 4         Guardian readers: are you all whingers?
# ..                                            ...
# 95                                     The Casket
# 96     Net Imperative joins dot.com casualty list
# 97  Mikhail Pletnev/ Philharmonia/ Vladimir Conta
# 98              Money Channel signs with Telewest
# 99                            Boos from the crowd
#
#                                                  Top6  \
# 0   Depleted Leicester prevail as Elliott spoils E...
# 1                              Has Cubie killed fees?
# 2                                 England on the rack
# 3   Auntie back in fashion, even if the dress look...
# 4                                    Hollywood Beyond
# ..                                                ...
# 95                                          Pop music
# 96                   Bank that's just you and the web
# 97                             Solitude and seascapes
# 98                                      The final cut
# 99               Whitbread calls last orders for beer
#
#                                                Top7  \
# 0                  Hungry Spurs sense rich pickings
# 1                            Has Cubie killed fees?
# 2   Pakistan retaliate with call for video of Walsh
# 3                     Shoaib appeal goes to the top
# 4                                Ashes and diamonds
# ..                                              ...
# 95                 In the temple of artistic jokers
# 96          Should you be paid for travelling time?
# 97                       Rebels raise takeover fear
# 98                           Susan Hiller's Witness
# 99             Microsoft falls on analyst's warning
#
#                                                  Top8  ...  \
# 0                   Gunners so wide of an easy target  ...
# 1                              Has Cubie killed fees?  ...
# 2                Cullinan continues his Cape monopoly  ...
# 3   Hussain hurt by 'shambles' but lays blame on e...  ...
# 4                    Whingers - a formidable minority  ...
# ..                                                ...  ...
# 95                                              Audio  ...
# 96                                                 xx  ...
# 97                                       Bye bye Boos  ...
# 98                                Gleeful musical tag  ...
# 99        Dot.com chill cuts Egg share for executives  ...
#
#                                                 Top16  \
# 0            Flintoff injury piles on woe for England
# 1                                On the critical list
# 2                         South Melbourne (Australia)
# 3   Putin admits Yeltsin quit to give him a head s...
# 4                              Most everywhere:  UDIs
# ..                                                ...
# 95                                        Firefighter
# 96             'Most disappointing ever for Zimbabwe'
# 97                      Party's over for dot.com IPOs
# 98                         Marathon man of the crease
# 99           Lively Francis leaves Warne in the shade
#
#                                                 Top17  \
# 0   Hunters threaten Jospin with new battle of the...
# 1                           The timing of their lives
# 2                                     Necaxa (Mexico)
# 3          BBC worst hit as digital TV begins to bite
# 4                        Most wanted:  Chloe lunettes
# ..                                                ...
# 95         Former Sun editor Larry Lamb dies, aged 71
# 96                 King takes gloss off Nazir's knock
# 97                        Egg reviews flotation plans
# 98  Kirtley's three strikes put smile back on Adam...
# 99               He had it all - but it wasn't enough
#
#                                                 Top18  \
# 0                 Kohl's successor drawn into scandal
# 1                                         Dear doctor
# 2                                 Real Madrid (Spain)
# 3                         How much can you pay for...
# 4      Return of the cane 'completely off the agenda'
# ..                                                ...
# 95                                         Radio days
# 96  Trescothick hits the high notes to drown out S...
# 97                         As Meninas/Candid Festival
# 98        Kent cry foul as Dravid leads Indian exodus
# 99    Quarter-finals, semi-finals and final 1999-2000
#
#                                                 Top19  \
# 0                The difference between men and women
# 1   Irish court halts IRA man's extradition to Nor...
# 2                           Raja Casablanca (Morocco)
# 3                                  Christmas glitches
# 4                    From Sleepy Hollow to Greeneland
# ..                                                ...
# 95                 It's the economy - don't be stupid
# 96         Graveney moves to prevent insider gambling
# 97                   Breaks for the England bandwagon
# 98                    Spanish ready to serve up feast
# 99  Australian murder trial dropped after web 'pre...
#
#                                                 Top20  \
# 0                 Sara Denver, nurse turned solicitor
# 1   Burundi peace initiative fades after rebels re...
# 2                                Corinthians (Brazil)
# 3   Upending a table, Chopping a line and Scoring ...
# 4               Blunkett outlines vision for over 11s
# ..                                                ...
# 95  Lever looks to develop employees' artistic skills
# 96                           Calamity ends the tedium
# 97                Adams returns to scene of Law abuse
# 98                      No Giggs and no joy for Wales
# 99                              Cross-media ownership
#
#                                                 Top21  \
# 0      Diana's landmine crusade put Tories in a panic
# 1                PE points the way forward to the ECB
# 2                                  Tony's pet project
# 3    Scientific evidence 'unreliable', defence claims
# 4   Embattled Dobson attacks 'play now, pay later'...
# ..                                                ...
# 95                                Platitudes in sound
# 96  Vialli does little to clear up clear-out confu...
# 97                          Footsore Razzaq digs deep
# 98            Celtic tempt O'Neill with £2m wage bait
# 99                Orchard of Spain crumbles into dust
#
#                                                 Top22  \
# 0   Yeltsin's resignation caught opposition flat-f...
# 1   Campaigners keep up pressure on Nazi war crime...
# 2                             Al Nassr (Saudi Arabia)
# 3      Fusco wins judicial review in extradition case
# 4                                   Doom and the Dome
# ..                                                ...
# 95                                Unfinished business
# 96                   Hearts grab second Uefa Cup spot
# 97             Barry fills England's void on the left
# 98                Loose-limbed Owen defies the doubts
# 99                 Thank God for the Champions League
#
#                                                 Top23  \
# 0                                    Russian roulette
# 1                                      Jane Ratcliffe
# 2                                   Ideal Holmes show
# 3                       Rebels thwart Russian advance
# 4                     What is the north-south divide?
# ..                                                ...
# 95  Panic selling of hi-tech stocks follows crash ...
# 96      Copenhagen 15 will be banished from Euro 2000
# 97               Fizzing Keegan savours the big stage
# 98                         Real Madrid 3 - 0 Valencia
# 99  Absolute nonsense, Absolute disgrace and Absol...
#
#                                                 Top24  \
# 0                                            Sold out
# 1   Yet more things you wouldn't know without the ...
# 2                Pinochet leaves hospital after tests
# 3                Blair orders shake-up of failing NHS
# 4                           Aitken released from jail
# ..                                                ...
# 95                    Liquidators in weekend of talks
# 96  It's rusk or bust for Wise and friends in foot...
# 97               Veteran Hässler back in German squad
# 98             Belgians 'fear the worst' at Charleroi
# 99      Prescott tells rail firms to improve services
#
#                                               Top25
# 0                                Recovering a title
# 1                      Millennium bug fails to bite
# 2                                      Useful links
# 3                       Lessons of law's hard heart
# 4                                        Gone aloft
# ..                                              ...
# 95                            From gofer to partner
# 96  Boateng hits at Wise and claims he was targeted
# 97                 England keep looking to the left
# 98                                  Waterloo sunset
# 99         Tony rushes in where Bill fears to tread
#
# [100 rows x 27 columns]

# %%
#We are splitting are data using Time Based Splitting 
train = df[df["Date"] <  '20150101']    #data is in the format of yyyy-dd-mm
print("------train Dataset lenght-----\n",train.shape)
test = df[df["Date"] > '20141231']
print("------test Dataset-----\n",test.shape)
# Out:
# ------train Dataset lenght-----
#  (3975, 27)
# ------test Dataset-----
#  (378, 27)

# %%
data = train.iloc[:,2:27]
#print(data)
data.replace("[^a-zA-Z]"," ",regex=True,inplace = True)

#Renaming Columns for ease
list1 = [i for i in range(25)]
new_Index = [str(i) for i in list1]  #Since i string , as it is not compatible , so we are converting into string format
data.columns = new_Index
data.head(5)
# Out:
#                                                    0  \
# 0  A  hindrance to operations   extracts from the...
# 1                                          Scorecard
# 2                  Coventry caught on counter by Flo
# 3                      Pilgrim knows how to progress
# 4                               Hitches and Horlocks
#
#                                     1  \
# 0                           Scorecard
# 1                 The best lake scene
# 2  United s rivals on the road to Rio
# 3                 Thatcher facing ban
# 4      Beckham off but United survive
#
#                                                2  \
# 0                Hughes  instant hit buoys Blues
# 1                  Leader  German sleaze inquiry
# 2  Thatcher issues defence before trial by video
# 3        McIlroy calls for Irish fighting spirit
# 4                        Breast cancer screening
#
#                                                3  \
# 0       Jack gets his skates on at ice cold Alex
# 1                                  Cheerio  boyo
# 2  Police help Smith lay down the law at Everton
# 3                Leicester bin stadium blueprint
# 4                                    Alan Parker
#
#                                              4  \
# 0       Chaos as Maracana builds up for United
# 1                     The main recommendations
# 2  Tale of Trautmann bears two more retellings
# 3               United braced for Mexican wave
# 4      Guardian readers  are you all whingers
#
#                                                    5  \
# 0  Depleted Leicester prevail as Elliott spoils E...
# 1                             Has Cubie killed fees
# 2                                England on the rack
# 3  Auntie back in fashion  even if the dress look...
# 4                                   Hollywood Beyond
#
#                                                  6  \
# 0                 Hungry Spurs sense rich pickings
# 1                           Has Cubie killed fees
# 2  Pakistan retaliate with call for video of Walsh
# 3                    Shoaib appeal goes to the top
# 4                               Ashes and diamonds
#
#                                                    7  \
# 0                  Gunners so wide of an easy target
# 1                             Has Cubie killed fees
# 2               Cullinan continues his Cape monopoly
# 3  Hussain hurt by  shambles  but lays blame on e...
# 4                   Whingers   a formidable minority
#
#                                                    8  \
# 0      Derby raise a glass to Strupar s debut double
# 1  Hopkins  furious  at Foster s lack of Hannibal...
# 2             McGrath puts India out of their misery
# 3                      England s decade of disasters
# 4                             Alan Parker   part two
#
#                                           9  ...  \
# 0  Southgate strikes  Leeds pay the penalty  ...
# 1                    Has Cubie killed fees   ...
# 2            Blair Witch bandwagon rolls on  ...
# 3      Revenge is sweet for jubilant Cronje  ...
# 4                 Thuggery  Toxins and Ties  ...
#
#                                                   15  \
# 0           Flintoff injury piles on woe for England
# 1                               On the critical list
# 2                        South Melbourne  Australia
# 3  Putin admits Yeltsin quit to give him a head s...
# 4                             Most everywhere   UDIs
#
#                                                   16  \
# 0  Hunters threaten Jospin with new battle of the...
# 1                          The timing of their lives
# 2                                    Necaxa  Mexico
# 3         BBC worst hit as digital TV begins to bite
# 4                       Most wanted   Chloe lunettes
#
#                                                17  \
# 0             Kohl s successor drawn into scandal
# 1                                     Dear doctor
# 2                             Real Madrid  Spain
# 3                     How much can you pay for
# 4  Return of the cane  completely off the agenda
#
#                                                   18  \
# 0               The difference between men and women
# 1  Irish court halts IRA man s extradition to Nor...
# 2                          Raja Casablanca  Morocco
# 3                                 Christmas glitches
# 4                   From Sleepy Hollow to Greeneland
#
#                                                   19  \
# 0                Sara Denver  nurse turned solicitor
# 1  Burundi peace initiative fades after rebels re...
# 2                               Corinthians  Brazil
# 3  Upending a table  Chopping a line and Scoring ...
# 4              Blunkett outlines vision for over   s
#
#                                                   20  \
# 0     Diana s landmine crusade put Tories in a panic
# 1               PE points the way forward to the ECB
# 2                                 Tony s pet project
# 3   Scientific evidence  unreliable   defence claims
# 4  Embattled Dobson attacks  play now  pay later ...
#
#                                                   21  \
# 0  Yeltsin s resignation caught opposition flat f...
# 1  Campaigners keep up pressure on Nazi war crime...
# 2                            Al Nassr  Saudi Arabia
# 3     Fusco wins judicial review in extradition case
# 4                                  Doom and the Dome
#
#                                 22  \
# 0                 Russian roulette
# 1                   Jane Ratcliffe
# 2                Ideal Holmes show
# 3    Rebels thwart Russian advance
# 4  What is the north south divide
#
#                                                   23  \
# 0                                           Sold out
# 1  Yet more things you wouldn t know without the ...
# 2               Pinochet leaves hospital after tests
# 3               Blair orders shake up of failing NHS
# 4                          Aitken released from jail
#
#                              24
# 0            Recovering a title
# 1  Millennium bug fails to bite
# 2                  Useful links
# 3   Lessons of law s hard heart
# 4                    Gone aloft
#
# [5 rows x 25 columns]

# %%
for index in new_Index:
    #print(data[index])
    data[index] = data[index].str.lower()  # data[0] -> 0th row -> since it is a string type object 
data.head()
# Out:
#                                                    0  \
# 0  a  hindrance to operations   extracts from the...
# 1                                          scorecard
# 2                  coventry caught on counter by flo
# 3                      pilgrim knows how to progress
# 4                               hitches and horlocks
#
#                                     1  \
# 0                           scorecard
# 1                 the best lake scene
# 2  united s rivals on the road to rio
# 3                 thatcher facing ban
# 4      beckham off but united survive
#
#                                                2  \
# 0                hughes  instant hit buoys blues
# 1                  leader  german sleaze inquiry
# 2  thatcher issues defence before trial by video
# 3        mcilroy calls for irish fighting spirit
# 4                        breast cancer screening
#
#                                                3  \
# 0       jack gets his skates on at ice cold alex
# 1                                  cheerio  boyo
# 2  police help smith lay down the law at everton
# 3                leicester bin stadium blueprint
# 4                                    alan parker
#
#                                              4  \
# 0       chaos as maracana builds up for united
# 1                     the main recommendations
# 2  tale of trautmann bears two more retellings
# 3               united braced for mexican wave
# 4      guardian readers  are you all whingers
#
#                                                    5  \
# 0  depleted leicester prevail as elliott spoils e...
# 1                             has cubie killed fees
# 2                                england on the rack
# 3  auntie back in fashion  even if the dress look...
# 4                                   hollywood beyond
#
#                                                  6  \
# 0                 hungry spurs sense rich pickings
# 1                           has cubie killed fees
# 2  pakistan retaliate with call for video of walsh
# 3                    shoaib appeal goes to the top
# 4                               ashes and diamonds
#
#                                                    7  \
# 0                  gunners so wide of an easy target
# 1                             has cubie killed fees
# 2               cullinan continues his cape monopoly
# 3  hussain hurt by  shambles  but lays blame on e...
# 4                   whingers   a formidable minority
#
#                                                    8  \
# 0      derby raise a glass to strupar s debut double
# 1  hopkins  furious  at foster s lack of hannibal...
# 2             mcgrath puts india out of their misery
# 3                      england s decade of disasters
# 4                             alan parker   part two
#
#                                           9  ...  \
# 0  southgate strikes  leeds pay the penalty  ...
# 1                    has cubie killed fees   ...
# 2            blair witch bandwagon rolls on  ...
# 3      revenge is sweet for jubilant cronje  ...
# 4                 thuggery  toxins and ties  ...
#
#                                                   15  \
# 0           flintoff injury piles on woe for england
# 1                               on the critical list
# 2                        south melbourne  australia
# 3  putin admits yeltsin quit to give him a head s...
# 4                             most everywhere   udis
#
#                                                   16  \
# 0  hunters threaten jospin with new battle of the...
# 1                          the timing of their lives
# 2                                    necaxa  mexico
# 3         bbc worst hit as digital tv begins to bite
# 4                       most wanted   chloe lunettes
#
#                                                17  \
# 0             kohl s successor drawn into scandal
# 1                                     dear doctor
# 2                             real madrid  spain
# 3                     how much can you pay for
# 4  return of the cane  completely off the agenda
#
#                                                   18  \
# 0               the difference between men and women
# 1  irish court halts ira man s extradition to nor...
# 2                          raja casablanca  morocco
# 3                                 christmas glitches
# 4                   from sleepy hollow to greeneland
#
#                                                   19  \
# 0                sara denver  nurse turned solicitor
# 1  burundi peace initiative fades after rebels re...
# 2                               corinthians  brazil
# 3  upending a table  chopping a line and scoring ...
# 4              blunkett outlines vision for over   s
#
#                                                   20  \
# 0     diana s landmine crusade put tories in a panic
# 1               pe points the way forward to the ecb
# 2                                 tony s pet project
# 3   scientific evidence  unreliable   defence claims
# 4  embattled dobson attacks  play now  pay later ...
#
#                                                   21  \
# 0  yeltsin s resignation caught opposition flat f...
# 1  campaigners keep up pressure on nazi war crime...
# 2                            al nassr  saudi arabia
# 3     fusco wins judicial review in extradition case
# 4                                  doom and the dome
#
#                                 22  \
# 0                 russian roulette
# 1                   jane ratcliffe
# 2                ideal holmes show
# 3    rebels thwart russian advance
# 4  what is the north south divide
#
#                                                   23  \
# 0                                           sold out
# 1  yet more things you wouldn t know without the ...
# 2               pinochet leaves hospital after tests
# 3               blair orders shake up of failing nhs
# 4                          aitken released from jail
#
#                              24
# 0            recovering a title
# 1  millennium bug fails to bite
# 2                  useful links
# 3   lessons of law s hard heart
# 4                    gone aloft
#
# [5 rows x 25 columns]

# %%
headlines = []
for row in range(0,len(data.index)):
    headlines.append(' '.join(str(x) for x in data.iloc[row,0:25]))

print(headlines[3])
# Out:
# pilgrim knows how to progress thatcher facing ban mcilroy calls for irish fighting spirit leicester bin stadium blueprint united braced for mexican wave auntie back in fashion  even if the dress looks a bit tatty shoaib appeal goes to the top hussain hurt by  shambles  but lays blame on earlier damage england s decade of disasters revenge is sweet for jubilant cronje our choice  not theirs profile of former us nazi party officer william pierce new evidence shows record of war crimes suspect was not investigated the rise of the supernerds written on the body putin admits yeltsin quit to give him a head start bbc worst hit as digital tv begins to bite how much can you pay for    christmas glitches upending a table  chopping a line and scoring a goal scientific evidence  unreliable   defence claims fusco wins judicial review in extradition case rebels thwart russian advance blair orders shake up of failing nhs lessons of law s hard heart

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

# %%
countVect = CountVectorizer(ngram_range=(3,3))
Traindataset = countVect.fit_transform(headlines)

# %%
randomClassifier = RandomForestClassifier(n_estimators=200,criterion='entropy')
randomClassifier.fit(Traindataset,train['Label'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
TestData = []
for row in range(0,len(test.index)):
    TestData.append(' '.join(str(x) for x in test.iloc[row,2:27]))    
test_dataset = countVect.transform(TestData)
pred = randomClassifier.predict(test_dataset)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
matrix = confusion_matrix(test['Label'],pred)
print(matrix)
acc = accuracy_score(test['Label'],pred)
print("="*127)
print(acc)
report = classification_report(test['Label'],pred)
print("="*127)
print(report)
# Out:
# [[132  54]
#  [  1 191]]
# ===============================================================================================================================
# 0.8544973544973545
# ===============================================================================================================================
#               precision    recall  f1-score   support
#
#            0       0.99      0.71      0.83       186
#            1       0.78      0.99      0.87       192
#
#     accuracy                           0.85       378
#    macro avg       0.89      0.85      0.85       378
# weighted avg       0.88      0.85      0.85       378
